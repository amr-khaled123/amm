# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# vizualization data with matplotlib

# %%
df = pd.read_csv('out.csv')
df
# Out:
#    Unnamed: 0               job  salary  hours        time
# 0           0  machine learning   10000      6   2024-8-21
# 1           1           backend    9000      8    2024-9-3
# 2           2          frontend    8000     10  2024-10-15
# 3           3     data analysis   11000      9   2024-9-14

# %%
pyl = plt.pie(df.hours)
pyl
# Out:
# ([<matplotlib.patches.Wedge at 0x1b632d257c0>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, ''),
#   Text(-0.35977481863407124, 1.0395008801712586, ''),
#   Text(-0.9777189391775435, -0.5040492793106041, ''),
#   Text(0.7203469417807291, -0.8313244152959488, '')])

# %%
pll = plt.pie(df.salary)
pll.count(4)
# Out:
# 0

# %%
pyl1 = plt.plot(df.salary)
pyl1
