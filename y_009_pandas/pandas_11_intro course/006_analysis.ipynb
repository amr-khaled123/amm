# %%
import pandas as pd
# Out:
# C:\Users\AB\AppData\Local\Temp\ipykernel_43716\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("A:\\csv data\\Datasets-master\\Datasets-master\\movie_rec\\ratings.csv")
df1 = pd.read_csv(
    "A:\\csv data\\Datasets-master\\Datasets-master\\movie_rec\\movies.csv")

# %%
df.info()
print('*'*20)
df1.info()

# %%
df1['genres'].value_counts()

# %%
print(df['rating'].min())
print(df['rating'].idxmin())

# %%
df

# %%
x = df.groupby('movieId').rating.agg(['min','max','mean'])

# %%
x
# Out:
#          min  max      mean
# movieId
# 1        1.0  5.0  3.907328
# 2        0.5  5.0  3.353261
# 3        1.0  5.0  3.189655
# 4        1.0  4.0  2.818182
# 5        1.5  5.0  3.250000
# ...      ...  ...       ...
# 146684   4.0  4.0  4.000000
# 146878   2.5  2.5  2.500000
# 148238   3.0  3.0  3.000000
# 148626   4.0  4.5  4.333333
# 149532   4.0  4.0  4.000000
#
# [10325 rows x 3 columns]

# %%
a = pd.DataFrame(x)

# %%
a['index'] = range(1,10326)

# %%
a
# Out:
#          min  max      mean
# movieId
# 1        1.0  5.0  3.907328
# 2        0.5  5.0  3.353261
# 3        1.0  5.0  3.189655
# 4        1.0  4.0  2.818182
# 5        1.5  5.0  3.250000
# ...      ...  ...       ...
# 146684   4.0  4.0  4.000000
# 146878   2.5  2.5  2.500000
# 148238   3.0  3.0  3.000000
# 148626   4.0  4.5  4.333333
# 149532   4.0  4.0  4.000000
#
# [10325 rows x 3 columns]

# %%
a.to_csv('A:\\csv data\\Datasets-master\\Datasets-master\\movie_rec\\rate_sort.csv')

# %%
a

# %%
df1

# %%
df1[df1['movieId']==32153]

# %%
dff = pd.read_csv(
    "A:\\csv data\\Datasets-master\\Datasets-master\\Christmas Data\\train.csv")

# %%
dff

# %%
dff['Class'].value_counts()

# %% [markdown]
# Analysis

# %%
happy_df = pd.read_csv(
    "A:\\csv data\\Datasets-master\\Datasets-master\\World Happiness Data\\2020.csv")

# %%
happy_df

# %%
happy_df.tail(20)

# %%
happy_df[happy_df['Country name']=='Egypt']

# %%
happy_df.describe()

# %%
happy_df.info()

# %%
happy_df.groupby('Ladder score').count()
# Out:
#               Country name  Regional indicator  \
# Ladder score
# 2.5669                   1                   1
# 2.8166                   1                   1
# 3.2992                   1                   1
# 3.3123                   1                   1
# 3.4759                   1                   1
# ...                    ...                 ...
# 7.4880                   1                   1
# 7.5045                   1                   1
# 7.5599                   1                   1
# 7.6456                   1                   1
# 7.8087                   1                   1
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Ladder score
# 2.5669                                     1             1             1
# 2.8166                                     1             1             1
# 3.2992                                     1             1             1
# ...

# %%
print(happy_df['Country name'].count())

# %%
happy_df.groupby('Ladder score').describe()
# Out:
#              Standard error of ladder score                                    \
#                                       count      mean std       min       25%
# Ladder score
# 2.5669                                  1.0  0.031311 NaN  0.031311  0.031311
# 2.8166                                  1.0  0.107610 NaN  0.107610  0.107610
# 3.2992                                  1.0  0.058674 NaN  0.058674  0.058674
# 3.3123                                  1.0  0.052425 NaN  0.052425  0.052425
# 3.4759                                  1.0  0.115183 NaN  0.115183  0.115183
# ...                                     ...       ...  ..       ...       ...
# 7.4880                                  1.0  0.034837 NaN  0.034837  0.034837
# 7.5045                                  1.0  0.059616 NaN  0.059616  0.059616
# 7.5599                                  1.0  0.035014 NaN  0.035014  0.035014
# 7.6456                                  1.0  0.033492 NaN  0.033492  0.033492
# ...
