# %%
import pandas as pd
# Out:
# C:\Users\AB\AppData\Local\Temp\ipykernel_35928\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('out.csv')
from IPython.display import display
with pd.option_context('display.max_rows',4):
  display(df[df.salary>8500])
# Out:
#    Unnamed: 0               job  salary  hours       time
# 0           0  machine learning   10000      6  2024-8-21
# 1           1           backend    9000      8   2024-9-3
# 3           3     data analysis   11000      9  2024-9-14

# %%
df.sort_values('salary')
# Out:
#    Unnamed: 0               job  salary  hours        time
# 2           2          frontend    8000     10  2024-10-15
# 1           1           backend    9000      8    2024-9-3
# 0           0  machine learning   10000      6   2024-8-21
# 3           3     data analysis   11000      9   2024-9-14

# %%
df.sort_values('hours')
# Out:
#    Unnamed: 0               job  salary  hours        time
# 0           0  machine learning   10000      6   2024-8-21
# 1           1           backend    9000      8    2024-9-3
# 3           3     data analysis   11000      9   2024-9-14
# 2           2          frontend    8000     10  2024-10-15

# %%
df.loc[1:3]
# Out:
#    Unnamed: 0            job  salary  hours        time
# 1           1        backend    9000      8    2024-9-3
# 2           2       frontend    8000     10  2024-10-15
# 3           3  data analysis   11000      9   2024-9-14

# %%
df.loc[::-1]
# Out:
#    Unnamed: 0               job  salary  hours        time
# 3           3     data analysis   11000      9   2024-9-14
# 2           2          frontend    8000     10  2024-10-15
# 1           1           backend    9000      8    2024-9-3
# 0           0  machine learning   10000      6   2024-8-21

# %%
df.iloc[0:2]
# Out:
#    Unnamed: 0               job  salary  hours       time
# 0           0  machine learning   10000      6  2024-8-21
# 1           1           backend    9000      8   2024-9-3

# %%
df.iloc[1]
# Out:
# Unnamed: 0           1
# job            backend
# salary            9000
# hours                8
# time          2024-9-3
# Name: 1, dtype: object

# %%
df.salary.sum()
# Out:
# 38000

# %%
df.sample()
# Out:
#    Unnamed: 0               job  salary  hours       time
# 0           0  machine learning   10000      6  2024-8-21

# %% [markdown]
# convert to time string to date

# %%
df['time'] = pd.to_datetime(df.time)
df['time']
# Out:
# 0   2024-08-21
# 1   2024-09-03
# 2   2024-10-15
# 3   2024-09-14
# Name: time, dtype: datetime64[ns]

# %%
df['time'].sort_values()
# Out:
# 0   2024-08-21
# 1   2024-09-03
# 3   2024-09-14
# 2   2024-10-15
# Name: time, dtype: datetime64[ns]

# %%
df['time'].sort_index()
# Out:
# 0   2024-08-21
# 1   2024-09-03
# 2   2024-10-15
# 3   2024-09-14
# Name: time, dtype: datetime64[ns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['year'] = pd.DatetimeIndex(df.time).year
df['month'] = pd.DatetimeIndex(df.time).month
df['day'] = pd.DatetimeIndex(df.time).day

# %%
df
# Out:
#    Unnamed: 0               job  salary  hours       time  year  month  day
# 0           0  machine learning   10000      6 2024-08-21  2024      8   21
# 1           1           backend    9000      8 2024-09-03  2024      9    3
# 2           2          frontend    8000     10 2024-10-15  2024     10   15
# 3           3     data analysis   11000      9 2024-09-14  2024      9   14

# %%
df
# Out:
#    Unnamed: 0               job  salary  hours       time  year  month  day
# 0           0  machine learning   10000      6 2024-08-21  2024      8   21
# 1           1           backend    9000      8 2024-09-03  2024      9    3
# 2           2          frontend    8000     10 2024-10-15  2024     10   15
# 3           3     data analysis   11000      9 2024-09-14  2024      9   14

# %%
df_august = df[df.month==8]

# %%
df_august
# Out:
#    Unnamed: 0               job  salary  hours       time  year  month  day
# 0           0  machine learning   10000      6 2024-08-21  2024      8   21

# %%
df.salary.mean()
# Out:
# 9500.0

# %%
motor_df = pd.read_csv("A:\\csv data\\Electric_Vehicle_Population_Data.csv")

# %%
motor_df.info
# Out:
# <bound method DataFrame.info of         VIN (1-10)     County              City State  Postal Code  \
# 0       5UXTA6C0XM     Kitsap           Seabeck    WA      98380.0
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 2       WP0AD2A73G  Snohomish           Bothell    WA      98012.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 4       1N4AZ1CP3K       King           Redmond    WA      98052.0
# ...            ...        ...               ...   ...          ...
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210161  JM3KKBHA0R     Kitsap         Bremerton    WA      98312.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
# 210163  5YJ3E1EA1M       King          Kirkland    WA      98034.0
# 210164  7SAYGDEE0P    Spokane           Spokane    WA      99208.0
#
#         Model Year     Make       Model  \
# 0             2021      BMW          X5
# 1             2018    TESLA     MODEL 3
# ...

# %%
motor_df.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year     Make  \
# 0  5UXTA6C0XM     Kitsap    Seabeck    WA      98380.0        2021      BMW
# 1  5YJ3E1EB1J     Kitsap    Poulsbo    WA      98370.0        2018    TESLA
# 2  WP0AD2A73G  Snohomish    Bothell    WA      98012.0        2016  PORSCHE
# 3  5YJ3E1EB5J     Kitsap  Bremerton    WA      98310.0        2018    TESLA
# 4  1N4AZ1CP3K       King    Redmond    WA      98052.0        2019   NISSAN
#
#       Model                   Electric Vehicle Type  \
# 0        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1   MODEL 3          Battery Electric Vehicle (BEV)
# 2  PANAMERA  Plug-in Hybrid Electric Vehicle (PHEV)
# 3   MODEL 3          Battery Electric Vehicle (BEV)
# 4      LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            30.0
# ...

# %%
motor_df.iloc[10:20]
# Out:
#     VIN (1-10)     County          City State  Postal Code  Model Year  \
# 10  1G1FX6S03H     Kitsap  Port Orchard    WA      98366.0        2017
# 11  5YJ3E1EA5K  Snohomish      Lynnwood    WA      98087.0        2019
# 12  JTMAB3FV5R     Kitsap       Poulsbo    WA      98370.0        2024
# 13  5YJSA1DPXC   Thurston       Olympia    WA      98502.0        2012
# 14  YV4H60LF5R     Yakima        Yakima    WA      98908.0        2024
# 15  5YJYGDEF8L  Snohomish       Edmonds    WA      98026.0        2020
# 16  5YJ3E1EA6L       King        Duvall    WA      98019.0        2020
# 17  1C4RJXN64R   Thurston       Olympia    WA      98502.0        2024
# 18  5YJSA1H28F       King       Bothell    WA      98011.0        2015
# 19  5YJ3E1EB7K       King       Seattle    WA      98115.0        2019
#
#          Make       Model                   Electric Vehicle Type  \
# 10  CHEVROLET     BOLT EV          Battery Electric Vehicle (BEV)
# ...

# %%
motor_df[motor_df['Electric Range']>310][motor_df['Model Year']==2020].iloc[10:20]
# Out:
# C:\Users\AB\AppData\Local\Temp\ipykernel_35928\956075574.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   motor_df[motor_df['Electric Range']>310][motor_df['Model Year']==2020].iloc[10:20]
#       VIN (1-10)    County             City State  Postal Code  Model Year  \
# 1512  5YJ3E1EB5L   Stevens  Nine Mile Falls    WA      99026.0        2020
# 1526  5YJ3E1EB8L      King         Kirkland    WA      98033.0        2020
# 1754  5YJ3E1EB5L      King           Auburn    WA      98092.0        2020
# 1759  5YJ3E1EB0L      King           Renton    WA      98058.0        2020
# 1984  5YJ3E1EB4L      King        Sammamish    WA      98075.0        2020
# 2210  5YJ3E1EB5L  Thurston         Tumwater    WA      98501.0        2020
# 2297  5YJ3E1EB8L      King         Bellevue    WA      98008.0        2020
# 2431  5YJSA1E25L      King         Kirkland    WA      98033.0        2020
# ...
