# %% [markdown]
# example1

# %%
import random
salary_list = [random.randint(1000,15000) for _ in range(1000000)]
salary_list
# Out:
# [13586,
#  11646,
#  9657,
#  10953,
#  7050,
#  2761,
#  13376,
#  10370,
#  14773,
#  8691,
#  4342,
#  4122,
#  1759,
#  10158,
#  14578,
#  7730,
#  6234,
#  5497,
#  2579,
#  2446,
#  1294,
#  9128,
#  2344,
#  9958,
#  6837,
#  12274,
#  9753,
#  9618,
#  14506,
#  12670,
#  1111,
#  11992,
#  2147,
#  8516,
#  9379,
#  9114,
#  12987,
#  10285,
#  11499,
#  1446,
#  2904,
#  14668,
#  11137,
#  8896,
#  4396,
#  9183,
#  6846,
#  12242,
#  9381,
#  6579,
#  13654,
#  5244,
#  4691,
#  5091,
#  9347,
#  4120,
#  13470,
#  12661,
#  9215,
#  7817,
#  10076,
#  12411,
#  3648,
#  14562,
#  4682,
#  9084,
#  9851,
#  14153,
#  10732,
#  3926,
#  5415,
#  8420,
#  2351,
#  12115,
#  7256,
#  1589,
#  11309,
#  3700,
#  7962,
#  6366,
#  1819,
#  7596,
#  9886,
#  14740,
#  2552,
#  10254,
#  12233,
#  11152,
#  10302,
#  9447,
#  6977,
#  13401,
#  7620,
#  5473,
#  6148,
#  14175,
#  4684,
#  2451,
#  11077,
#  7508,
#  13612,
#  4725,
#  4429,
#  6837,
#  3422,
#  6940,
#  2587,
# ...

# %% [markdown]
# example2

# %%
import numpy as np
salary_list1 = np.random.randint(15000,size=(4,50))
print(salary_list1)
np.mean(salary_list1)
# Out:
# [[12684 14251  9115  2049  5329 10023  4105  1130 13824 13730  4606  4086
#    5085  2741 10988  7955 11246  6243  3819  3955  3427  4350 12633  5262
#    8362 14763  9178 11189  8607  4806  9907 13623   947  4269    14  6615
#     980  3982   653  5054   994  4744 13092   331 11978 10375   709  4106
#   13287 11335]
#  [13519  4604 11286  5814  9629   123 12986 10828  9621 14737 14012  1783
#    6189  8126  4149 12033 11405   758  3427 12597  2949  4450 11503 10755
#    9243 13756  9260  5243 11001 12645  7191  8192 14387  4764 13140  3494
#    7783  3170 10681  1423 12362  6760 13216  7842  6425 10210 10142 11530
#    1983 13566]
#  [ 6930 14850  5482 12432  6984  2359  5214  3383  3342  1285 10029 11698
#    8567 14894  7545   532  5513  6432    39 10680 11716  5144  7058   843
#    8761  8462 10982 14868 11745  3217  5703  1586  6694 14037 11426  2978
#     463  3296 13037  5799  7403 13751  9135  3801  6585  7476  1060    66
#   10804 12196]
# ...

# %% [markdown]
# Numpy

# %%
import numpy as np
job_titles = np.array(['data scientist','machine learning','data analysis','data engineer'])
salary = np.array([10000,12000,20000,15000])
salary_bonus = np.array([0.1,0.08,0.04,0.06])

# %%
total_salary = salary*(1+salary_bonus)
total_salary
# Out:
# array([11000., 12960., 20800., 15900.])

# %%
np.mean(total_salary)
# Out:
# 15165.0

# %% [markdown]
# Pandas

# %%
import pandas as pd
# Out:
# C:\Users\AB\AppData\Local\Temp\ipykernel_27184\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# transform from dictionary to csv and data frame

# %%
dic = { 'job':['machine learning','backend','frontend','data analysis'],
        'salary':[10000,9000,8000,11000],
        'hours': [6,8,10,9],
        'time': ['2024-8-21', '2024-9-3', '2024-10-15', '2024-9-14']}

df = pd.DataFrame(dic)
df.to_csv('out.csv')
df
# Out:
#                 job  salary  hours        time
# 0  machine learning   10000      6   2024-8-21
# 1           backend    9000      8    2024-9-3
# 2          frontend    8000     10  2024-10-15
# 3     data analysis   11000      9   2024-9-14

# %% [markdown]
# Read csv

# %%
df = pd.read_csv('out.csv')
df
# Out:
#    Unnamed: 0               job  salary  hours        time
# 0           0  machine learning   10000      6   2024-8-21
# 1           1           backend    9000      8    2024-9-3
# 2           2          frontend    8000     10  2024-10-15
# 3           3     data analysis   11000      9   2024-9-14

# %% [markdown]
# Describe data and get mean and standard deviation

# %%
df.describe()
# Out:
#        Unnamed: 0        salary      hours
# count    4.000000      4.000000   4.000000
# mean     1.500000   9500.000000   8.250000
# std      1.290994   1290.994449   1.707825
# min      0.000000   8000.000000   6.000000
# 25%      0.750000   8750.000000   7.500000
# 50%      1.500000   9500.000000   8.500000
# 75%      2.250000  10250.000000   9.250000
# max      3.000000  11000.000000  10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      int64
#  1   job         4 non-null      object
#  2   salary      4 non-null      int64
#  3   hours       4 non-null      int64
#  4   time        4 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# Columns of csv

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'job', 'salary', 'hours', 'time'], dtype='object')

# %% [markdown]
# shape of data

# %%
df.shape
# Out:
# (4, 5)

# %% [markdown]
# slice data

# %%
df.at[2,'job']
# Out:
# 'frontend'

# %% [markdown]
# get data from head

# %%
df.head(2)
# Out:
#    Unnamed: 0               job  salary  hours       time
# 0           0  machine learning   10000      6  2024-8-21
# 1           1           backend    9000      8   2024-9-3

# %% [markdown]
# get data from tail

# %%
df.tail(2)
# Out:
#    Unnamed: 0            job  salary  hours        time
# 2           2       frontend    8000     10  2024-10-15
# 3           3  data analysis   11000      9   2024-9-14

# %% [markdown]
# call data slice with out indexing

# %%
#same as df['job']
df.job
# Out:
# 0    machine learning
# 1             backend
# 2            frontend
# 3       data analysis
# Name: job, dtype: object

# %%
jods_df = df.copy()
jods_df
# Out:
#    Unnamed: 0               job  salary  hours        time
# 0           0  machine learning   10000      6   2024-8-21
# 1           1           backend    9000      8    2024-9-3
# 2           2          frontend    8000     10  2024-10-15
# 3           3     data analysis   11000      9   2024-9-14

# %%
df1 = df.salary>9000
df1
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: salary, dtype: bool

# %%
df.salary[df1]
# Out:
# 0    10000
# 3    11000
# Name: salary, dtype: int64
