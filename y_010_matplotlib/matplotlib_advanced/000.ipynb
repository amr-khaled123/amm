# %% [markdown]
# Matplotlib Intro

# %%
import pandas as pd
from datasets import load_dataset

#loading data set
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date']) # type: ignore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df[['job_posted_date','job_title_short']]
# Out:
#            job_posted_date       job_title_short
# 0      2023-06-16 13:44:15  Senior Data Engineer
# 1      2023-01-14 13:18:07          Data Analyst
# 2      2023-10-10 13:14:55         Data Engineer
# 3      2023-07-04 13:01:41         Data Engineer
# 4      2023-08-07 14:29:36         Data Engineer
# ...                    ...                   ...
# 785736 2023-03-13 06:16:16     Software Engineer
# 785737 2023-03-12 06:18:18          Data Analyst
# 785738 2023-03-12 06:32:36      Business Analyst
# 785739 2023-03-12 06:32:15         Data Engineer
# 785740 2023-03-13 06:16:31     Software Engineer
#
# [785741 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = ['a','b','c']
y = [4,5,6]
plt.bar(x,y)
plt.show()

# %%
x = ['a', 'b', 'c']
y = [4, 5, 6]
plt.plot(x, y)
plt.show()

# %%
x = ['a', 'b', 'c','d']
y = [2, 4, 6,8]
plt.bar(x,y)
plt.grid(True)

# %%
date_counts = df.job_posted_date.value_counts()
date_counts
# Out:
# job_posted_date
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: count, Length: 607192, dtype: int64

# %%
date_counts = date_counts.sort_index()

# %%
plt.plot(date_counts.index,date_counts)

# %% [markdown]
# make month columns

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df[['job_posted_month']]
# Out:
#         job_posted_month
# 0                      6
# 1                      1
# 2                     10
# 3                      7
# 4                      8
# ...                  ...
# 785736                 3
# 785737                 3
# 785738                 3
# 785739                 3
# 785740                 3
#
# [785741 rows x 1 columns]

# %%
date_counts = df.job_posted_month.value_counts()
date_counts
# Out:
# job_posted_month
# 1     91822
# 8     75162
# 10    66611
# 2     64578
# 11    64450
# 3     64084
# 7     63777
# 4     62919
# 9     62359
# 6     61572
# 12    56303
# 5     52104
# Name: count, dtype: int64

# %%
date_counts = date_counts.sort_index()
date_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(date_counts.index,date_counts)

# %%
df['job_posted_day'] = df.job_posted_date.dt.day_name()
df[['job_posted_day']]
# Out:
#        job_posted_day
# 0              Friday
# 1            Saturday
# 2             Tuesday
# 3             Tuesday
# 4              Monday
# ...               ...
# 785736         Monday
# 785737         Sunday
# 785738         Sunday
# 785739         Sunday
# 785740         Monday
#
# [785741 rows x 1 columns]

# %%
date_counts = df['job_posted_day'].value_counts()
date_counts = date_counts.sort_index()
date_counts
# Out:
# job_posted_day
# Friday       126328
# Monday       108063
# Saturday      90174
# Sunday        81962
# Thursday     127251
# Tuesday      125000
# Wednesday    126963
# Name: count, dtype: int64

# %%
plt.plot(date_counts.index,date_counts)

# %%
plt.bar(date_counts.index, date_counts)
# Out:
# <BarContainer object of 7 artists>

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
job_counts = df['job_title_short'].value_counts()

# %%
plt.bar(job_counts.index,job_counts)
plt.xlabel('Job_Title')
plt.xticks(rotation = 45,ha='right')
plt.title('jobs visualization')
plt.show()

# %%
plt.barh(job_counts.index, job_counts)
plt.ylabel('Job_Title')
plt.xticks(rotation=45,ha='right')
plt.title('jobs visualization')
plt.show()

# %%
job_counts = job_counts.sort_values(ascending=True)

# %%
plt.barh(job_counts.index, job_counts)
plt.ylabel('Job_Title')
plt.xticks(rotation=90)
plt.title('jobs visualization')
plt.show()

# %%
plt.pie(job_counts, labels=job_counts.index, autopct='%1.2f%%')
plt.title('My Customized Pie Chart', fontsize=14, color='red')
plt.show()

# %%
def func(y):
    return 2*y
y = [1,2,3]
x =list(map(func,y))
plt.bar(x,y)
plt.show()

# %%
job_counts.plot(kind='bar').can_zoom()
# Out:
# True

# %%
df.groupby('job_title_short')['salary_year_avg'].median().sort_values()
# Out:
# <bound method Series.sort_values of job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64>

# %%
job_mean_salary = df.groupby('job_title_short')['salary_year_avg'].mean().sort_values()

# %%
job_mean_salary.plot(kind='barh')
# Out:
# <Axes: ylabel='job_title_short'>
